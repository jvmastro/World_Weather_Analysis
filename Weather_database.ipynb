# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
import requests
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | jiayuguan
# Processing Record 6 of Set 1 | capinopolis
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | lanzhou
# Processing Record 10 of Set 1 | atar
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | kwinana
# Processing Record 13 of Set 1 | mecca
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | itarema
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | columbus
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | college
# Processing Record 23 of Set 1 | minot
# Processing Record 24 of Set 1 | celestun
# Processing Record 25 of Set 1 | kagadi
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | yanam
# Processing Record 30 of Set 1 | hami
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | praia da vitoria
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | gualaquiza
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 1 | zemio
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | caucaia
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | shimoda
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | san andres
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | iwanai
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | dungarvan
# Processing Record 5 of Set 2 | kachug
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | dwarahat
# Processing Record 8 of Set 2 | izhma
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | constitucion
# Processing Record 12 of Set 2 | karratha
# Processing Record 13 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | padang
# Processing Record 16 of Set 2 | changping
# Processing Record 17 of Set 2 | brokopondo
# Processing Record 18 of Set 2 | tibati
# Processing Record 19 of Set 2 | rayachoti
# Processing Record 20 of Set 2 | sao paulo de olivenca
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | lobatse
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | sukhobezvodnoye
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | chabahar
# Processing Record 29 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 2 | pevek
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | dzhebariki-khaya
# Processing Record 36 of Set 2 | solnechnyy
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | raudeberg
# Processing Record 39 of Set 2 | bonavista
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | bairiki
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | antsohihy
# Processing Record 46 of Set 2 | port hardy
# Processing Record 47 of Set 2 | geraldton
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | gidam
# Processing Record 50 of Set 2 | progreso
# Processing Record 1 of Set 3 | bereda
# Processing Record 2 of Set 3 | san patricio
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | balabac
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | qaqortoq
# Processing Record 7 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 3 | freeport
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 3 | dhuwaran
# Processing Record 11 of Set 3 | kapaa
# Processing Record 12 of Set 3 | lardos
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | esmeraldas
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | rondonopolis
# Processing Record 17 of Set 3 | niono
# Processing Record 18 of Set 3 | katsuura
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | lavrentiya
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | akdepe
# Processing Record 24 of Set 3 | karhal
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | anan
# Processing Record 27 of Set 3 | kaeo
# Processing Record 28 of Set 3 | evensk
# Processing Record 29 of Set 3 | marsh harbour
# Processing Record 30 of Set 3 | anadyr
# Processing Record 31 of Set 3 | carora
# Processing Record 32 of Set 3 | uige
# Processing Record 33 of Set 3 | lagoa
# Processing Record 34 of Set 3 | sao miguel do guama
# Processing Record 35 of Set 3 | kuloy
# Processing Record 36 of Set 3 | sinnamary
# Processing Record 37 of Set 3 | kinablangan
# Processing Record 38 of Set 3 | maniitsoq
# Processing Record 39 of Set 3 | hirtshals
# Processing Record 40 of Set 3 | ornskoldsvik
# Processing Record 41 of Set 3 | palm springs
# Processing Record 42 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 3 | gornyy
# Processing Record 44 of Set 3 | flinders
# Processing Record 45 of Set 3 | yellowknife
# Processing Record 46 of Set 3 | kapuskasing
# Processing Record 47 of Set 3 | mananara
# Processing Record 48 of Set 3 | dudinka
# Processing Record 49 of Set 3 | bloemhof
# Processing Record 50 of Set 3 | liwale
# Processing Record 1 of Set 4 | druzhba
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | saurimo
# Processing Record 4 of Set 4 | mapastepec
# Processing Record 5 of Set 4 | korsakov
# Processing Record 6 of Set 4 | mana
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | komsomolskiy
# Processing Record 9 of Set 4 | san cristobal
# Processing Record 10 of Set 4 | sukhinichi
# Processing Record 11 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 4 | zaysan
# Processing Record 14 of Set 4 | quatre cocos
# Processing Record 15 of Set 4 | asadabad
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | gat
# Processing Record 18 of Set 4 | whitianga
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 4 | viedma
# Processing Record 22 of Set 4 | cheney
# Processing Record 23 of Set 4 | cap malheureux
# Processing Record 24 of Set 4 | kholm
# Processing Record 25 of Set 4 | adre
# Processing Record 26 of Set 4 | mao
# Processing Record 27 of Set 4 | verkhoyansk
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | kapoeta
# Processing Record 30 of Set 4 | majene
# Processing Record 31 of Set 4 | perambalur
# Processing Record 32 of Set 4 | muisne
# Processing Record 33 of Set 4 | victoria
# Processing Record 34 of Set 4 | bengkulu
# Processing Record 35 of Set 4 | klaksvik
# Processing Record 36 of Set 4 | issoudun
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | shizunai
# Processing Record 41 of Set 4 | murud
# Processing Record 42 of Set 4 | rabo de peixe
# Processing Record 43 of Set 4 | mandalgovi
# Processing Record 44 of Set 4 | fort nelson
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | cairns
# Processing Record 47 of Set 4 | makakilo city
# Processing Record 48 of Set 4 | ponta delgada
# Processing Record 49 of Set 4 | valparaiso
# Processing Record 50 of Set 4 | sao filipe
# Processing Record 1 of Set 5 | shelburne
# Processing Record 2 of Set 5 | asifabad
# Processing Record 3 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 4 of Set 5 | sumkino
# Processing Record 5 of Set 5 | abha
# Processing Record 6 of Set 5 | samarai
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | porbandar
# Processing Record 9 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 5 | dzaoudzi
# Processing Record 12 of Set 5 | lasa
# Processing Record 13 of Set 5 | kichera
# Processing Record 14 of Set 5 | ushtobe
# Processing Record 15 of Set 5 | rajsamand
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | aykhal
# Processing Record 18 of Set 5 | poum
# Processing Record 19 of Set 5 | gornopravdinsk
# Processing Record 20 of Set 5 | yar-sale
# Processing Record 21 of Set 5 | talakan
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | salina cruz
# Processing Record 24 of Set 5 | petit goave
# Processing Record 25 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 5 | saskylakh
# Processing Record 27 of Set 5 | harper
# Processing Record 28 of Set 5 | paracuru
# Processing Record 29 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 5 | talara
# Processing Record 31 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | mount gambier
# Processing Record 34 of Set 5 | harlingen
# Processing Record 35 of Set 5 | fortuna
# Processing Record 36 of Set 5 | dwarka
# Processing Record 37 of Set 5 | aksarka
# Processing Record 38 of Set 5 | vegueta
# Processing Record 39 of Set 5 | yumen
# Processing Record 40 of Set 5 | monrovia
# Processing Record 41 of Set 5 | dunedin
# Processing Record 42 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 5 | moron
# Processing Record 44 of Set 5 | emerald
# Processing Record 45 of Set 5 | beyneu
# Processing Record 46 of Set 5 | ambon
# Processing Record 47 of Set 5 | mehran
# Processing Record 48 of Set 5 | durango
# Processing Record 49 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 5 | caravelas
# Processing Record 1 of Set 6 | kenora
# Processing Record 2 of Set 6 | bishna
# City not found. Skipping...
# Processing Record 3 of Set 6 | verkhnyaya inta
# Processing Record 4 of Set 6 | sedhiou
# Processing Record 5 of Set 6 | gwadar
# Processing Record 6 of Set 6 | jishou
# Processing Record 7 of Set 6 | port lincoln
# Processing Record 8 of Set 6 | chuy
# Processing Record 9 of Set 6 | dapdap
# Processing Record 10 of Set 6 | itaueira
# Processing Record 11 of Set 6 | mahebourg
# Processing Record 12 of Set 6 | tsurib
# Processing Record 13 of Set 6 | ishigaki
# Processing Record 14 of Set 6 | kalmunai
# Processing Record 15 of Set 6 | tepalcingo
# Processing Record 16 of Set 6 | owo
# Processing Record 17 of Set 6 | lukovetskiy
# Processing Record 18 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | torbay
# Processing Record 22 of Set 6 | sola
# Processing Record 23 of Set 6 | kavieng
# Processing Record 24 of Set 6 | east moline
# Processing Record 25 of Set 6 | baykit
# Processing Record 26 of Set 6 | alice springs
# Processing Record 27 of Set 6 | tautira
# Processing Record 28 of Set 6 | sungairaya
# Processing Record 29 of Set 6 | jinxi
# Processing Record 30 of Set 6 | yatou
# Processing Record 31 of Set 6 | sawakin
# Processing Record 32 of Set 6 | acarau
# Processing Record 33 of Set 6 | san policarpo
# Processing Record 34 of Set 6 | kudahuvadhoo
# Processing Record 35 of Set 6 | darhan
# Processing Record 36 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 37 of Set 6 | columbia
# Processing Record 38 of Set 6 | sernovodskoye
# Processing Record 39 of Set 6 | srednekolymsk
# Processing Record 40 of Set 6 | arlit
# Processing Record 41 of Set 6 | cortes
# Processing Record 42 of Set 6 | kalengwa
# Processing Record 43 of Set 6 | trebinje
# Processing Record 44 of Set 6 | vila do maio
# Processing Record 45 of Set 6 | tutoia
# Processing Record 46 of Set 6 | bulungu
# Processing Record 47 of Set 6 | baruun-urt
# Processing Record 48 of Set 6 | hamilton
# Processing Record 49 of Set 6 | grand gaube
# Processing Record 50 of Set 6 | nara
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 2 of Set 7 | kang
# Processing Record 3 of Set 7 | bose
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | yulara
# Processing Record 6 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 7 | adeje
# Processing Record 8 of Set 7 | sambava
# Processing Record 9 of Set 7 | kidal
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | bulgan
# Processing Record 12 of Set 7 | kintampo
# Processing Record 13 of Set 7 | tessalit
# Processing Record 14 of Set 7 | luang prabang
# Processing Record 15 of Set 7 | veraval
# Processing Record 16 of Set 7 | roebourne
# Processing Record 17 of Set 7 | bokovskaya
# Processing Record 18 of Set 7 | rocha
# Processing Record 19 of Set 7 | kabompo
# Processing Record 20 of Set 7 | naze
# Processing Record 21 of Set 7 | termoli
# Processing Record 22 of Set 7 | hobyo
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | pacific grove
# Processing Record 25 of Set 7 | port hedland
# Processing Record 26 of Set 7 | george town
# Processing Record 27 of Set 7 | shu
# Processing Record 28 of Set 7 | coahuayana
# Processing Record 29 of Set 7 | zaraza
# Processing Record 30 of Set 7 | lebu
# Processing Record 31 of Set 7 | kaitangata
# Processing Record 32 of Set 7 | limon
# Processing Record 33 of Set 7 | nadvoitsy
# Processing Record 34 of Set 7 | kutum
# Processing Record 35 of Set 7 | salmas
# Processing Record 36 of Set 7 | hoquiam
# Processing Record 37 of Set 7 | batabano
# Processing Record 38 of Set 7 | cartagena del chaira
# Processing Record 39 of Set 7 | korla
# Processing Record 40 of Set 7 | ajdabiya
# Processing Record 41 of Set 7 | luanda
# Processing Record 42 of Set 7 | curup
# Processing Record 43 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 7 | meulaboh
# Processing Record 45 of Set 7 | waingapu
# Processing Record 46 of Set 7 | durban
# Processing Record 47 of Set 7 | egvekinot
# Processing Record 48 of Set 7 | sebeta
# Processing Record 49 of Set 7 | bambanglipuro
# Processing Record 50 of Set 7 | cidreira
# Processing Record 1 of Set 8 | chaihe
# Processing Record 2 of Set 8 | notodden
# Processing Record 3 of Set 8 | ulladulla
# Processing Record 4 of Set 8 | aketi
# Processing Record 5 of Set 8 | carnarvon
# Processing Record 6 of Set 8 | portland
# Processing Record 7 of Set 8 | okhotsk
# Processing Record 8 of Set 8 | meadow lake
# Processing Record 9 of Set 8 | san carlos de bariloche
# Processing Record 10 of Set 8 | ancud
# Processing Record 11 of Set 8 | cuamba
# Processing Record 12 of Set 8 | bumba
# Processing Record 13 of Set 8 | anloga
# Processing Record 14 of Set 8 | beira
# Processing Record 15 of Set 8 | vostok
# Processing Record 16 of Set 8 | luxeuil-les-bains
# Processing Record 17 of Set 8 | broken hill
# Processing Record 18 of Set 8 | tarko-sale
# Processing Record 19 of Set 8 | provideniya
# Processing Record 20 of Set 8 | iqaluit
# Processing Record 21 of Set 8 | lorengau
# Processing Record 22 of Set 8 | hooksett
# Processing Record 23 of Set 8 | lata
# Processing Record 24 of Set 8 | iralaya
# Processing Record 25 of Set 8 | ormara
# Processing Record 26 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 27 of Set 8 | santiago
# Processing Record 28 of Set 8 | guerrero negro
# Processing Record 29 of Set 8 | swan hill
# Processing Record 30 of Set 8 | tara
# Processing Record 31 of Set 8 | huangpi
# Processing Record 32 of Set 8 | narsaq
# Processing Record 33 of Set 8 | lac du bonnet
# Processing Record 34 of Set 8 | saldanha
# Processing Record 35 of Set 8 | fukue
# Processing Record 36 of Set 8 | puerto madero
# Processing Record 37 of Set 8 | nishihara
# Processing Record 38 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 8 | cockburn town
# Processing Record 40 of Set 8 | aviles
# Processing Record 41 of Set 8 | zhizdra
# Processing Record 42 of Set 8 | patiya
# Processing Record 43 of Set 8 | mount isa
# Processing Record 44 of Set 8 | namatanai
# Processing Record 45 of Set 8 | vladesti
# Processing Record 46 of Set 8 | zvenigovo
# Processing Record 47 of Set 8 | belle fourche
# Processing Record 48 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 8 | cayenne
# Processing Record 50 of Set 8 | sudak
# Processing Record 1 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | payette
# Processing Record 4 of Set 9 | henties bay
# Processing Record 5 of Set 9 | saint anthony
# Processing Record 6 of Set 9 | tadine
# Processing Record 7 of Set 9 | shenjiamen
# Processing Record 8 of Set 9 | qeshm
# Processing Record 9 of Set 9 | zomba
# Processing Record 10 of Set 9 | tukrah
# Processing Record 11 of Set 9 | tecoanapa
# Processing Record 12 of Set 9 | bitung
# Processing Record 13 of Set 9 | cavalcante
# Processing Record 14 of Set 9 | saint-joseph
# Processing Record 15 of Set 9 | araouane
# Processing Record 16 of Set 9 | tampere
# Processing Record 17 of Set 9 | cherskiy
# Processing Record 18 of Set 9 | purgstall
# Processing Record 19 of Set 9 | el tigre
# Processing Record 20 of Set 9 | inhambane
# Processing Record 21 of Set 9 | hervey bay
# Processing Record 22 of Set 9 | uvinza
# Processing Record 23 of Set 9 | nouadhibou
# Processing Record 24 of Set 9 | cuenca
# Processing Record 25 of Set 9 | saint-pierre
# Processing Record 26 of Set 9 | lugazi
# Processing Record 27 of Set 9 | wad madani
# Processing Record 28 of Set 9 | yingshang
# City not found. Skipping...
# Processing Record 29 of Set 9 | abu zabad
# Processing Record 30 of Set 9 | seoul
# Processing Record 31 of Set 9 | suntar
# Processing Record 32 of Set 9 | newcastle
# Processing Record 33 of Set 9 | antofagasta
# Processing Record 34 of Set 9 | coquimbo
# Processing Record 35 of Set 9 | north bend
# Processing Record 36 of Set 9 | maceio
# Processing Record 37 of Set 9 | la plata
# Processing Record 38 of Set 9 | alihe
# Processing Record 39 of Set 9 | kyabram
# Processing Record 40 of Set 9 | zhicheng
# Processing Record 41 of Set 9 | matoury
# Processing Record 42 of Set 9 | bilibino
# Processing Record 43 of Set 9 | snyder
# Processing Record 44 of Set 9 | port shepstone
# Processing Record 45 of Set 9 | grand-lahou
# Processing Record 46 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 47 of Set 9 | nouakchott
# Processing Record 48 of Set 9 | river falls
# Processing Record 49 of Set 9 | rolla
# Processing Record 50 of Set 9 | paldiski
# Processing Record 1 of Set 10 | vieux-habitants
# Processing Record 2 of Set 10 | talcahuano
# Processing Record 3 of Set 10 | ivdel
# Processing Record 4 of Set 10 | diffa
# Processing Record 5 of Set 10 | havoysund
# Processing Record 6 of Set 10 | soubre
# Processing Record 7 of Set 10 | eyl
# Processing Record 8 of Set 10 | tanabe
# Processing Record 9 of Set 10 | senno
# Processing Record 10 of Set 10 | fort pierce
# Processing Record 11 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 10 | te anau
# Processing Record 13 of Set 10 | isangel
# Processing Record 14 of Set 10 | malindi
# Processing Record 15 of Set 10 | kulhudhuffushi
# Processing Record 16 of Set 10 | ribeira grande
# Processing Record 17 of Set 10 | roald
# Processing Record 18 of Set 10 | muhos
# Processing Record 19 of Set 10 | lokosovo
# Processing Record 20 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 21 of Set 10 | berlevag
# Processing Record 22 of Set 10 | bonfim
# Processing Record 23 of Set 10 | isla mujeres
# Processing Record 24 of Set 10 | tshikapa
# Processing Record 25 of Set 10 | vila velha
# Processing Record 26 of Set 10 | kroya
# Processing Record 27 of Set 10 | tual
# Processing Record 28 of Set 10 | bam
# Processing Record 29 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 30 of Set 10 | homer
# Processing Record 31 of Set 10 | skjervoy
# Processing Record 32 of Set 10 | oktyabrskoye
# Processing Record 33 of Set 10 | harnosand
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | clarence town
# Processing Record 36 of Set 10 | baie du tombeau
# City not found. Skipping...
# Processing Record 37 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 10 | pitea
# Processing Record 39 of Set 10 | tiarei
# Processing Record 40 of Set 10 | uzhur
# Processing Record 41 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 10 | lesnoye
# Processing Record 43 of Set 10 | khed brahma
# Processing Record 44 of Set 10 | medea
# Processing Record 45 of Set 10 | hambantota
# Processing Record 46 of Set 10 | jumla
# Processing Record 47 of Set 10 | peniche
# Processing Record 48 of Set 10 | richards bay
# Processing Record 49 of Set 10 | roseau
# Processing Record 50 of Set 10 | le mars
# Processing Record 1 of Set 11 | kolpashevo
# Processing Record 2 of Set 11 | takoradi
# Processing Record 3 of Set 11 | mangochi
# Processing Record 4 of Set 11 | gimli
# Processing Record 5 of Set 11 | paisley
# Processing Record 6 of Set 11 | vaitape
# Processing Record 7 of Set 11 | tura
# Processing Record 8 of Set 11 | rapid valley
# Processing Record 9 of Set 11 | croy
# Processing Record 10 of Set 11 | chegdomyn
# Processing Record 11 of Set 11 | kantang
# Processing Record 12 of Set 11 | bandarbeyla
# Processing Record 13 of Set 11 | pangai
# Processing Record 14 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 11 | kisangani
# Processing Record 16 of Set 11 | vestmannaeyjar
# Processing Record 17 of Set 11 | bilma
# Processing Record 18 of Set 11 | gemunden
# Processing Record 19 of Set 11 | malegaon
# Processing Record 20 of Set 11 | buala
# Processing Record 21 of Set 11 | morros
# Processing Record 22 of Set 11 | le havre
# Processing Record 23 of Set 11 | russell
# Processing Record 24 of Set 11 | jizan
# Processing Record 25 of Set 11 | marandahalli
# Processing Record 26 of Set 11 | salalah
# Processing Record 27 of Set 11 | zhezkazgan
# Processing Record 28 of Set 11 | nabire
# Processing Record 29 of Set 11 | kahului
# Processing Record 30 of Set 11 | puerto colombia
# Processing Record 31 of Set 11 | tabou
# Processing Record 32 of Set 11 | sangar
# Processing Record 33 of Set 11 | la romana
# Processing Record 34 of Set 11 | ascension
# Processing Record 35 of Set 11 | ballina
# Processing Record 36 of Set 11 | bidar
# Processing Record 37 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 11 | aloleng
# Processing Record 39 of Set 11 | changji
# Processing Record 40 of Set 11 | los llanos de aridane
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | tiznit
# Processing Record 43 of Set 11 | alofi
# Processing Record 44 of Set 11 | kurilsk
# Processing Record 45 of Set 11 | avesta
# Processing Record 46 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 11 | luangwa
# Processing Record 48 of Set 11 | muros
# Processing Record 49 of Set 11 | tezu
# Processing Record 50 of Set 11 | port blair
# Processing Record 1 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 12 | beloha
# Processing Record 3 of Set 12 | nekrasovka
# Processing Record 4 of Set 12 | tres picos
# Processing Record 5 of Set 12 | zhanaozen
# Processing Record 6 of Set 12 | maldonado
# Processing Record 7 of Set 12 | saint-denis
# Processing Record 8 of Set 12 | fuerte olimpo
# Processing Record 9 of Set 12 | camacha
# Processing Record 10 of Set 12 | sassandra
# Processing Record 11 of Set 12 | cambridge
# Processing Record 12 of Set 12 | pasighat
# Processing Record 13 of Set 12 | bathsheba
# Processing Record 14 of Set 12 | calafell
# Processing Record 15 of Set 12 | fomboni
# Processing Record 16 of Set 12 | ahipara
# Processing Record 17 of Set 12 | hokitika
# Processing Record 18 of Set 12 | pekan
# Processing Record 19 of Set 12 | vanimo
# Processing Record 20 of Set 12 | broome
# Processing Record 21 of Set 12 | woodward
# Processing Record 22 of Set 12 | kropotkin
# Processing Record 23 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 12 | aban
# Processing Record 25 of Set 12 | fairbanks
# Processing Record 26 of Set 12 | hays
# Processing Record 27 of Set 12 | togur
# Processing Record 28 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 29 of Set 12 | moerai
# Processing Record 30 of Set 12 | estevan
# Processing Record 31 of Set 12 | cutro
# Processing Record 32 of Set 12 | ambilobe
# Processing Record 33 of Set 12 | viradouro
# Processing Record 34 of Set 12 | key largo
# Processing Record 35 of Set 12 | nerl
# Processing Record 36 of Set 12 | myanaung
# Processing Record 37 of Set 12 | devonport
# Processing Record 38 of Set 12 | awallan
# Processing Record 39 of Set 12 | luba
# Processing Record 40 of Set 12 | khilchipur
# Processing Record 41 of Set 12 | lima
# Processing Record 42 of Set 12 | port macquarie
# Processing Record 43 of Set 12 | saint-georges
# Processing Record 44 of Set 12 | belyy yar
# Processing Record 45 of Set 12 | buraydah
# Processing Record 46 of Set 12 | litovko
# Processing Record 47 of Set 12 | sarkand
# Processing Record 48 of Set 12 | zhigansk
# Processing Record 49 of Set 12 | jiwani
# Processing Record 50 of Set 12 | itaituba
# Processing Record 1 of Set 13 | chicama
# Processing Record 2 of Set 13 | caucasia
# Processing Record 3 of Set 13 | ewa beach
# Processing Record 4 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 5 of Set 13 | ulaangom
# Processing Record 6 of Set 13 | ivolginsk
# Processing Record 7 of Set 13 | san joaquin
# Processing Record 8 of Set 13 | maple creek
# Processing Record 9 of Set 13 | amapa
# Processing Record 10 of Set 13 | immokalee
# Processing Record 11 of Set 13 | kieta
# Processing Record 12 of Set 13 | teguldet
# Processing Record 13 of Set 13 | raichur
# Processing Record 14 of Set 13 | amuntai
# Processing Record 15 of Set 13 | dingle
# Processing Record 16 of Set 13 | udachnyy
# Processing Record 17 of Set 13 | wattegama
# Processing Record 18 of Set 13 | tarauaca
# Processing Record 19 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 13 | marawi
# Processing Record 21 of Set 13 | ihtiman
# Processing Record 22 of Set 13 | teknaf
# Processing Record 23 of Set 13 | danielskuil
# Processing Record 24 of Set 13 | bridlington
# Processing Record 25 of Set 13 | manokwari
# Processing Record 26 of Set 13 | tagusao
# Processing Record 27 of Set 13 | guanhaes
# Processing Record 28 of Set 13 | maxixe
# Processing Record 29 of Set 13 | wucheng
# Processing Record 30 of Set 13 | oktyabrskiy
# Processing Record 31 of Set 13 | dutlwe
# Processing Record 32 of Set 13 | samfya
# Processing Record 33 of Set 13 | ossora
# Processing Record 34 of Set 13 | ocala
# Processing Record 35 of Set 13 | borogontsy
# Processing Record 36 of Set 13 | huainan
# Processing Record 37 of Set 13 | nizhniy kuranakh
# Processing Record 38 of Set 13 | goure
# Processing Record 39 of Set 13 | san jeronimo
# Processing Record 40 of Set 13 | puerto baquerizo moreno
# Processing Record 41 of Set 13 | tucuman
# Processing Record 42 of Set 13 | ilulissat
# Processing Record 43 of Set 13 | najran
# Processing Record 44 of Set 13 | linxia
# Processing Record 45 of Set 13 | nador
# Processing Record 46 of Set 13 | churapcha
# Processing Record 47 of Set 13 | zhaotong
# Processing Record 48 of Set 13 | marihatag
# Processing Record 49 of Set 13 | sovetskiy
# Processing Record 50 of Set 13 | milazzo
# Processing Record 1 of Set 14 | port keats
# Processing Record 2 of Set 14 | northam
# Processing Record 3 of Set 14 | nanton
# Processing Record 4 of Set 14 | chimbote
# Processing Record 5 of Set 14 | vila franca do campo
# Processing Record 6 of Set 14 | wanning
# Processing Record 7 of Set 14 | timizart
# Processing Record 8 of Set 14 | plettenberg bay
# Processing Record 9 of Set 14 | goderich
# Processing Record 10 of Set 14 | la ronge
# Processing Record 11 of Set 14 | kruisfontein
# Processing Record 12 of Set 14 | barra patuca
# Processing Record 13 of Set 14 | cabedelo
# Processing Record 14 of Set 14 | bozova
# Processing Record 15 of Set 14 | rawson
# Processing Record 16 of Set 14 | hirara
# Processing Record 17 of Set 14 | totma
# Processing Record 18 of Set 14 | cherdyn
# Processing Record 19 of Set 14 | les cayes
# Processing Record 20 of Set 14 | pandan
# Processing Record 21 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 23 of Set 14 | bafia
# Processing Record 24 of Set 14 | erenhot
# Processing Record 25 of Set 14 | sligo
# Processing Record 26 of Set 14 | itoman
# Processing Record 27 of Set 14 | manyana
# Processing Record 28 of Set 14 | bonthe
# Processing Record 29 of Set 14 | khor
# Processing Record 30 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 31 of Set 14 | sakaiminato
# Processing Record 32 of Set 14 | cutervo
# Processing Record 33 of Set 14 | tromso
# Processing Record 34 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 14 | faya
# Processing Record 36 of Set 14 | villamontes
# Processing Record 37 of Set 14 | wilmington
# Processing Record 38 of Set 14 | pangnirtung
# Processing Record 39 of Set 14 | sampit
# Processing Record 40 of Set 14 | olafsvik
# Processing Record 41 of Set 14 | sterling
# Processing Record 42 of Set 14 | igarka
# Processing Record 43 of Set 14 | aras
# Processing Record 44 of Set 14 | sistranda
# Processing Record 45 of Set 14 | obsharovka
# Processing Record 46 of Set 14 | vlakhokerasea
# City not found. Skipping...
# Processing Record 47 of Set 14 | perehonivka
# Processing Record 48 of Set 14 | carira
# Processing Record 49 of Set 14 | west wendover
# Processing Record 50 of Set 14 | pocoes
# Processing Record 1 of Set 15 | phatthalung
# Processing Record 2 of Set 15 | poso
# Processing Record 3 of Set 15 | rena
# Processing Record 4 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 5 of Set 15 | sur
# Processing Record 6 of Set 15 | aranda de duero
# Processing Record 7 of Set 15 | benjamin constant
# Processing Record 8 of Set 15 | derzhavinsk
# Processing Record 9 of Set 15 | mugur-aksy
# Processing Record 10 of Set 15 | luzhou
# Processing Record 11 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 12 of Set 15 | burica
# City not found. Skipping...
# Processing Record 13 of Set 15 | san vicente
# Processing Record 14 of Set 15 | lehututu
# Processing Record 15 of Set 15 | mbaiki
# Processing Record 16 of Set 15 | gazli
# Processing Record 17 of Set 15 | rosario
# Processing Record 18 of Set 15 | madimba
# Processing Record 19 of Set 15 | norden
# Processing Record 20 of Set 15 | naklo nad notecia
# Processing Record 21 of Set 15 | jawhar
# Processing Record 22 of Set 15 | neyvo-shaytanskiy
# Processing Record 23 of Set 15 | bay roberts
# Processing Record 24 of Set 15 | cordoba
# Processing Record 25 of Set 15 | conceicao do araguaia
# Processing Record 26 of Set 15 | kasongo
# Processing Record 27 of Set 15 | hazorasp
# Processing Record 28 of Set 15 | floro
# Processing Record 29 of Set 15 | morro bay
# Processing Record 30 of Set 15 | madison heights
# Processing Record 31 of Set 15 | zyryanskoye
# Processing Record 32 of Set 15 | bintulu
# Processing Record 33 of Set 15 | ivanivka
# Processing Record 34 of Set 15 | khani
# Processing Record 35 of Set 15 | manacapuru
# Processing Record 36 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 15 | pauini
# Processing Record 39 of Set 15 | oranjemund
# Processing Record 40 of Set 15 | gandai
# Processing Record 41 of Set 15 | sarahan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Airai      TL  -8.93  125.41     62.42       100         100
# 1        Dikson      RU  73.51   80.55    -27.26        84          47
# 2  Punta Arenas      CL -53.15  -70.92     53.60        62          75
# 3     Busselton      AU -33.65  115.33     51.01        92           0
# 4     Jiayuguan      CN  39.82   98.30     11.75        61          16
# 5   Capinopolis      BR -18.68  -49.57     81.73        59          92
# 6      Thompson      CA  55.74  -97.86     -9.40        69          90
# 7     Jamestown      US  42.10  -79.24     34.00        97          90
# 8       Lanzhou      CN  36.06  103.79     18.00        63           0
# 9          Atar      MR  20.52  -13.05     63.16        30           0
#
#    Wind Speed Current Description
# 0        3.22          light rain
# 1        7.20    scattered clouds
# 2       28.86       broken clouds
# 3       12.93           clear sky
# 4        1.72          few clouds
# 5        1.81          light rain
# 6        3.36     overcast clouds
# 7        6.93                 fog
# 8        1.10           clear sky
# 9       10.40           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
